# %% [markdown]
# i am learning from codanics
# i am learning devops basic
# 1- **first program**

# %%
print(3+4)
print("Assalam o Alaikum")
# Out:
# 7
# Assalam o Alaikum

# %% [markdown]
# **02_operators**

# %%
print(2+4)
print(4-4)
print(4*2)
print(8//4)
print(15%2)
print(5**2)
# Out:
# 6
# 0
# 8
# 2
# 1
# 25

# %% [markdown]
#  PEMDAS = PARENTHESIS EXPONENTS MULTIPLICATIONS DIVISION
#           # ADDITION SUBTRACTION
# left to right M D and A S

# %% [markdown]
# **03_strings**

# %%
print(3+4)
print("Assalam o Alaikum")
print('single')
print("double")
print('''triple''')

print("salman's")
# Out:
# 7
# Assalam o Alaikum
# single
# double
# triple
# salman's

# %% [markdown]
# **04_comments**

# %% [markdown]
# *# cntl + / to comment out and same for comment in*

# %% [markdown]
# **05_variables**
# **rules to assign a variable**
# # 1- the variables should contain letters, numbers and underscores.
# # 2- do not start with numbers
# # 3- spaces are not allowed
# # 4- do not use keywords used in functions (print,mean,fasle etc.)
# # 5- short and descriptive
# # 6- case sensitivity (lowercase, uppercase. lower case should be used.)

# %%
fruit_home= 6
fruit_home="grapes"
print(type(fruit_home))
print(fruit_home)
# Out:
# <class 'str'>
# grapes

# %% [markdown]
# **05_input variables**

# %%
fruit_home="grapes"
print(fruit_home)

# input function simple
fruit_home=input("your fav fruit? ")
print(fruit_home)

# 2nd stage input fun
name=input("what's your good name ? ")
greetings="Hello!"
print(greetings,name)

# another form of second stage input function
name=input("what's your good name ? ")
print("Hi!",name)

# 3rd stage input function
name=input('what is your name? ')
age=input("what is your age ? ")
greetings="welcome!"
print(greetings,name, ", u are young man")
# Out:
# grapes
# your fav fruit?  grapes
# grapes
# what's your good name ?  m salman
# Hello! m salman
# what's your good name ?  salman
# Hi! salman
# what is your name?  salman
# what is your age ?  6
# welcome! salman , u are young man

# %% [markdown]
# **07_logical conditions.**
# # logical operators are either "true or false", "yes or no" . "0 or 1"
# # is equal to               =
# # not equal to              !=
# # less than                 <
# # greater than              >
# # less than and equal to    <=
# # greater than and equal to  >=

# %%
print(4==4)
print(8!=7)
print(9<7)
print(7<=9)
print(7>4)

# applications of logical operators

my_age=79
age_vu=89
print(my_age==age_vu)

# input functions and logical operators

age_vu=89
my_age=input("what is ur age ? ")
# print(type(my_age)) convert input
my_age=int(my_age) 
print(my_age==age_vu)
# Out:
# True
# True
# False
# True
# True
# False
# what is ur age ?  6
# False

# %% [markdown]
# **08_typeconversion**

# %%
# integer 
x=7 
# float 
y=8.5
# string
z="Hi"

# implicit type conversion
x=x*y
print(x,(type(x)))

# explicit type conversion
age=input("What is your age ? ")
# age=int(age)
print(age, type(int(age)))

name=input("what's your name? ")
print(name, type(str(name)))
# Out:
# 59.5 <class 'float'>
# What is your age ?  6
# 6 <class 'int'>
# what's your name?  salman
# salman <class 'str'>

# %% [markdown]
# 09_**if_else_elif**

# %%
my_age=26
age_school=28

if my_age==age_school:
    print("congrats to school")
elif my_age>age_school:
    print("go to college.")
elif my_age<=20:
    print("try after required age")
    
else:
    print("sorry")
# Out:
# sorry

# %% [markdown]
# **10-functions**

# %%
# defining functions
# 1
def devops():
    print("I started devops on 9 sep 25")
    print("I started devops on 9 sep 25")
    print("I started devops on 9 sep 25")
devops()

# 2
def devops():
    text="I started devops on 9 sep 25 from AL Nafi."
    print(text)
    print(text)
devops()

# 3

def devops(text):
    print(text)
    print(text)
    print(text)
devops("I am a Devops engineer.")

# 4

# def a function by if , else and elif
def age_for_school(age):
    if age==6:
        print("welcome to school ")
    elif age> 6:
        print("join high school")
    else:
        print("u are baby")    
age_for_school(4)        

# 5

# defining future age

def future_age(age):
    new_age=age+35
    return new_age
    print(new_age)
future_prediction=future_age(5)    
print(future_prediction)
# Out:
# I started devops on 9 sep 25
# I started devops on 9 sep 25
# I started devops on 9 sep 25
# I started devops on 9 sep 25 from AL Nafi.
# I started devops on 9 sep 25 from AL Nafi.
# I am a Devops engineer.
# I am a Devops engineer.
# I am a Devops engineer.
# u are baby
# 40

# %% [markdown]
# **11_loops**

# %%
# # while loops
# x=0
# while (x<5):
#  print(x)
# x=x+1

#     # for loops
# for x in range(4,9):
#         print(x)

# # array

# days=["mon","tuesday","wednesday","thursday","fri","sat","sun"]
# for d in days:
#         # if (d=="fri"): loop breaks
#         if (d=="fri"): continue

#         print(d)

# %% [markdown]
# **12_import_libaries > numpy, pandas**

# %%
import math
print("the value of pi is", math.pi)

import statistics
x=[150,250,450]

print(statistics.mean(x))
# Out:
# the value of pi is 3.141592653589793
# 283.3333333333333

# %% [markdown]
# **13_troubleshooting**

# %%
# print(i am salman) syntax error

# print(20/0) runtime error

name= "salman"
# print("hi salman") semantic error
print("hi",name)
# Out:
# hi salman
