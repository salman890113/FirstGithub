# %%
# Body mass index
# input weight and height
# my height
# weight
# calculate BMI
# print BMI (my name is ---and my bmi is ---)

# %%
# weight in kg / height in meter and its square

# %%
height=input("What is your height")
height = float(height)
# Out:
# What is your height 6.7

# %%
weight = input("what is your weight")
weight = float (weight)
# Out:
# what is your weight 65

# %%
name = input("what is your name")
# Out:
# what is your name salman

# %%
Bmi = weight/height**2
Bmi
# Out:
# 1.4479839607930496

# %%
print("my name is",name,"and my Bmi is",Bmi)
# Out:
# my name is salman and my Bmi is 1.4479839607930496
